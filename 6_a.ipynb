# %% [markdown]
# <a href="https://colab.research.google.com/github/StellarSynapse/Lab_6/blob/main/6_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kwant
# Out:
# Collecting kwant
#   Downloading kwant-1.5.0.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from kwant) (1.26.4)
# Requirement already satisfied: scipy!=1.6.1,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from kwant) (1.13.1)
# Collecting tinyarray>=1.2.2 (from kwant)
#   Downloading tinyarray-1.2.4.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kwant, tinyarray
#   Building wheel for kwant (setup.py) ... done
#   Created wheel for kwant: filename=kwant-1.5.0-cp310-cp310-linux_x86_64.whl size=4195423 sha256=75e3d587be11b8044f902e202fa2fc792e7315ff90d7bd38583c4a2135cb08e8
#   Stored in directory: /root/.cache/pip/wheels/de/ed/a6/30c685d08edea4ac466fced410ca93fb46e5721a466b743a59
#   Building wheel for tinyarray (setup.py) ... done
#   Created wheel for tinyarray: filename=tinyarray-1.2.4-cp310-cp310-linux_x86_64.whl size=253581 sha256=dc1efdd68f2ff7fa352e0b1cdec92a6d87cf4823cbadd06e5e40a11d92d697a8
#   Stored in directory: /root/.cache/pip/wheels/dc/72/12/09ea11413b527aa3c3a5757ee615ee4d206ee77043a86cbce8
# Successfully built kwant tinyarray
# Installing collected packages: tinyarray, kwant
# Successfully installed kwant-1.5.0 tinyarray-1.2.4

# %%
from matplotlib import pyplot as plt
import kwant

# Функція для створення провідника
def make_lead(a=1, t=2.0, W=10):
    lat = kwant.lattice.square(a)
    sym_lead = kwant.TranslationalSymmetry((-a, 0))  # Симетрія трансляції
    lead = kwant.Builder(sym_lead)

    # Додаємо вузли до провідника
    for j in range(W):
        lead[lat(0, j)] = 4 * t
        if j > 0:
            lead[lat(0, j), lat(0, j - 1)] = -t  # Зв'язки вздовж Y
        lead[lat(1, j), lat(0, j)] = -t  # Зв'язки вздовж X

    return lead

# Основна функція
def main():
    # Генеруємо провідник
    lead = make_lead().finalized()

    # Малюємо графік енергетичних зон
    kwant.plotter.bands(lead, show=False)
    plt.xlabel("momentum [(lattice constant)^-1]")
    plt.ylabel("energy [t]")
    plt.title("Energy Bands of the Lead")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/kwant/solvers/default.py:16: RuntimeWarning: MUMPS is not available, SciPy built-in solver will be used as a fallback. Performance can be very poor in this case.
#   warnings.warn("MUMPS is not available, "
# /usr/local/lib/python3.10/dist-packages/kwant/lattice.py:746: KwantDeprecationWarning: Not specfying norbs is deprecated. Always specify norbs when creating site families.
#   return Monatomic(((a, 0), (0, a)), name=name, norbs=norbs)

# %%
from matplotlib import pyplot as plt
import kwant

# Функція для створення провідника
def make_lead(a=1, t=3.0, W=10):
    lat = kwant.lattice.square(a)
    sym_lead = kwant.TranslationalSymmetry((-a, 0))  # Симетрія трансляції
    lead = kwant.Builder(sym_lead)

    # Додаємо вузли до провідника
    for j in range(W):
        lead[lat(0, j)] = 4 * t
        if j > 0:
            lead[lat(0, j), lat(0, j - 1)] = -t  # Зв'язки вздовж Y
        lead[lat(1, j), lat(0, j)] = -t  # Зв'язки вздовж X

    return lead

# Основна функція
def main():
    # Генеруємо провідник
    lead = make_lead().finalized()

    # Малюємо графік енергетичних зон
    kwant.plotter.bands(lead, show=False)
    plt.xlabel("momentum [(lattice constant)^-1]")
    plt.ylabel("energy [t]")
    plt.title("Energy Bands of the Lead")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/kwant/lattice.py:746: KwantDeprecationWarning:
#
# Not specfying norbs is deprecated. Always specify norbs when creating site families.

# %%
from matplotlib import pyplot as plt
import kwant

# Функція для створення провідника
def make_lead(a=1, t=4.0, W=10):
    lat = kwant.lattice.square(a)
    sym_lead = kwant.TranslationalSymmetry((-a, 0))  # Симетрія трансляції
    lead = kwant.Builder(sym_lead)

    # Додаємо вузли до провідника
    for j in range(W):
        lead[lat(0, j)] = 4 * t
        if j > 0:
            lead[lat(0, j), lat(0, j - 1)] = -t  # Зв'язки вздовж Y
        lead[lat(1, j), lat(0, j)] = -t  # Зв'язки вздовж X

    return lead

# Основна функція
def main():
    # Генеруємо провідник
    lead = make_lead().finalized()

    # Малюємо графік енергетичних зон
    kwant.plotter.bands(lead, show=False)
    plt.xlabel("momentum [(lattice constant)^-1]")
    plt.ylabel("energy [t]")
    plt.title("Energy Bands of the Lead")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()

# %%
from matplotlib import pyplot as plt
import kwant

# Функція для створення провідника
def make_lead(a=1, t=5.0, W=10):
    lat = kwant.lattice.square(a)
    sym_lead = kwant.TranslationalSymmetry((-a, 0))  # Симетрія трансляції
    lead = kwant.Builder(sym_lead)

    # Додаємо вузли до провідника
    for j in range(W):
        lead[lat(0, j)] = 4 * t
        if j > 0:
            lead[lat(0, j), lat(0, j - 1)] = -t  # Зв'язки вздовж Y
        lead[lat(1, j), lat(0, j)] = -t  # Зв'язки вздовж X

    return lead

# Основна функція
def main():
    # Генеруємо провідник
    lead = make_lead().finalized()

    # Малюємо графік енергетичних зон
    kwant.plotter.bands(lead, show=False)
    plt.xlabel("momentum [(lattice constant)^-1]")
    plt.ylabel("energy [t]")
    plt.title("Energy Bands of the Lead")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
