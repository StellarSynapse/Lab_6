# %% [markdown]
# <a href="https://colab.research.google.com/github/StellarSynapse/Lab_6/blob/main/6_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kwant
# Out:
# Collecting kwant
#   Downloading kwant-1.5.0.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 31.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from kwant) (1.26.4)
# Requirement already satisfied: scipy!=1.6.1,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from kwant) (1.13.1)
# Collecting tinyarray>=1.2.2 (from kwant)
#   Downloading tinyarray-1.2.4.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kwant, tinyarray
#   Building wheel for kwant (setup.py) ... done
#   Created wheel for kwant: filename=kwant-1.5.0-cp310-cp310-linux_x86_64.whl size=4195423 sha256=96ac00a4e103ece424cf5cc4872cb2e26cec02850dfd70f962d5aea88c549183
#   Stored in directory: /root/.cache/pip/wheels/de/ed/a6/30c685d08edea4ac466fced410ca93fb46e5721a466b743a59
#   Building wheel for tinyarray (setup.py) ... done
#   Created wheel for tinyarray: filename=tinyarray-1.2.4-cp310-cp310-linux_x86_64.whl size=253578 sha256=c04c755d5a4934db46c7d9b314b9e16e9cb84596dd7564c4dbdf80edecbffa9f
#   Stored in directory: /root/.cache/pip/wheels/dc/72/12/09ea11413b527aa3c3a5757ee615ee4d206ee77043a86cbce8
# Successfully built kwant tinyarray
# Installing collected packages: tinyarray, kwant
# Successfully installed kwant-1.5.0 tinyarray-1.2.4

# %%
import kwant
import numpy as np
import tinyarray
# Out:
# /usr/local/lib/python3.10/dist-packages/kwant/solvers/default.py:16: RuntimeWarning: MUMPS is not available, SciPy built-in solver will be used as a fallback. Performance can be very poor in this case.
#   warnings.warn("MUMPS is not available, "

# %%
from matplotlib import pyplot

# %%
tau_x = tinyarray.array([[0,1],[1,0]])
tau_z = tinyarray.array([[1, 0], [0, -1]])
import matplotlib.pyplot as plt

# %%
def make_lead(a=1, t=1.0, mu=0.7, Delta=0.2, W=10):
    lat = kwant.lattice.square(a)
    sym_lead = kwant.TranslationalSymmetry((-a, 0))  # Симетрія трансляції
    lead = kwant.Builder(sym_lead)

    # Додаємо вузли до провідника
    for j in range(W):
        lead[lat(0, j)] = (4 * t-mu)*tau_z+Delta*tau_x
        if j > 0:
            lead[lat(0, j), lat(0, j - 1)] = -t*tau_z  # Зв'язки вздовж Y
        lead[lat(1, j), lat(0, j)] = -t*tau_z  # Зв'язки вздовж X

    return lead

# %%
def main():
    # Генеруємо провідник
    lead = make_lead().finalized()

    # Малюємо графік енергетичних зон
    kwant.plotter.bands(lead, momenta=np.linspace(-1.5,1.5,101), show=False)
    plt.xlabel("momentum [(lattice constant)^-1]")
    plt.ylabel("energy [t]")
    plt.title("Energy Bands of the Lead")
    plt.ylim([-0.8,0.8])
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/kwant/lattice.py:746: KwantDeprecationWarning:
#
# Not specfying norbs is deprecated. Always specify norbs when creating site families.

# %%
def make_lead(a=1, t=1.0, mu=0.7, Delta=0.3, W=10):
    lat = kwant.lattice.square(a)
    sym_lead = kwant.TranslationalSymmetry((-a, 0))  # Симетрія трансляції
    lead = kwant.Builder(sym_lead)

    # Додаємо вузли до провідника
    for j in range(W):
        lead[lat(0, j)] = (4 * t-mu)*tau_z+Delta*tau_x
        if j > 0:
            lead[lat(0, j), lat(0, j - 1)] = -t*tau_z  # Зв'язки вздовж Y
        lead[lat(1, j), lat(0, j)] = -t*tau_z  # Зв'язки вздовж X

    return lead

def main():
    # Генеруємо провідник
    lead = make_lead().finalized()

    # Малюємо графік енергетичних зон
    kwant.plotter.bands(lead, momenta=np.linspace(-1.5,1.5,101), show=False)
    plt.xlabel("momentum [(lattice constant)^-1]")
    plt.ylabel("energy [t]")
    plt.title("Energy Bands of the Lead")
    plt.ylim([-0.8,0.8])
    plt.show()

if __name__ == "__main__":
    main()

# %%
def make_lead(a=1, t=1.0, mu=0.7, Delta=0.4, W=10):
    lat = kwant.lattice.square(a)
    sym_lead = kwant.TranslationalSymmetry((-a, 0))  # Симетрія трансляції
    lead = kwant.Builder(sym_lead)

    # Додаємо вузли до провідника
    for j in range(W):
        lead[lat(0, j)] = (4 * t-mu)*tau_z+Delta*tau_x
        if j > 0:
            lead[lat(0, j), lat(0, j - 1)] = -t*tau_z  # Зв'язки вздовж Y
        lead[lat(1, j), lat(0, j)] = -t*tau_z  # Зв'язки вздовж X

    return lead

def main():
    # Генеруємо провідник
    lead = make_lead().finalized()

    # Малюємо графік енергетичних зон
    kwant.plotter.bands(lead, momenta=np.linspace(-1.5,1.5,101), show=False)
    plt.xlabel("momentum [(lattice constant)^-1]")
    plt.ylabel("energy [t]")
    plt.title("Energy Bands of the Lead")
    plt.ylim([-0.8,0.8])
    plt.show()

if __name__ == "__main__":
    main()

# %%
def make_lead(a=1, t=1.0, mu=0.7, Delta=0.5, W=10):
    lat = kwant.lattice.square(a)
    sym_lead = kwant.TranslationalSymmetry((-a, 0))  # Симетрія трансляції
    lead = kwant.Builder(sym_lead)

    # Додаємо вузли до провідника
    for j in range(W):
        lead[lat(0, j)] = (4 * t-mu)*tau_z+Delta*tau_x
        if j > 0:
            lead[lat(0, j), lat(0, j - 1)] = -t*tau_z  # Зв'язки вздовж Y
        lead[lat(1, j), lat(0, j)] = -t*tau_z  # Зв'язки вздовж X

    return lead

def main():
    # Генеруємо провідник
    lead = make_lead().finalized()

    # Малюємо графік енергетичних зон
    kwant.plotter.bands(lead, momenta=np.linspace(-1.5,1.5,101), show=False)
    plt.xlabel("momentum [(lattice constant)^-1]")
    plt.ylabel("energy [t]")
    plt.title("Energy Bands of the Lead")
    plt.ylim([-0.8,0.8])
    plt.show()

if __name__ == "__main__":
    main()
